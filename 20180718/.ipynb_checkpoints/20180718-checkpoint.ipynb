# %%
from IPython.display import display_html
display_html("""
<div style="text-align:left; margin: 20px 0;">
<p style="color:#FA5882;text-align:center; margin: 10px 0 20px 0;">
</p>
<button onclick="$('.input, .prompt, .output_stderr, .output_error').toggle();">折叠代码</button>
</div>
""", raw=True)
# Out:
# <div style="text-align:left; margin: 20px 0;">
# <p style="color:#FA5882;text-align:center; margin: 10px 0 20px 0;">
# </p>
# <button onclick="$('.input, .prompt, .output_stderr, .output_error').toggle();">折叠代码</button>
# </div>

# %%
import os
from IPython.display import FileLink
from IPython.display import Audio
base = '/home/zhx66/mnt/experiment/gst-guide/gst-tacotron-ljspeech/parallel-validate/0065/'
print("English: Neither the Dallas police nor the FBI had yet learned the source of the handbill.")
print("reference audio")
display(Audio(base+'LJ029-0065.wav'))
print("inference result")
display(Audio(base+'eval-315000_ref-LJ029-0065.wav'))


base = '/home/zhx66/mnt/experiment/gst-guide/gst-tacotron-ljspeech/parallel-validate/0235/'
print("English: I want forgiveness of man; I want those doors (of the prison) opened.")
print("reference audio")
display(Audio(base+'LJ014-0235.wav'))
print("inference result")
display(Audio(base+'eval-315000_ref-LJ014-0235.wav'))
# Out:
# English: Neither the Dallas police nor the FBI had yet learned the source of the handbill.
# reference audio
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# inference result
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# English: I want forgiveness of man; I want those doors (of the prison) opened.
# reference audio
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# inference result
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("==================CHINESE==================")
base = '/home/zhx66/mnt/experiment/gst-guide/gst-tacotron-ljspeech/parallel-validate/chinese/'
print("Chinese: d an4 b u4 zhi1 d ao5 pau0 y ou3 m ei2 y ou3 f eng4 h jieu ang2 b jiei an4 wu1 y a1 pau0")
print("但不知道有没有凤凰变乌鸦")
print("reference audio")
display(Audio(base+'csnt-140616-0050-140616-xijunm-0001-XIJUNM_0046614_0046884_M.wav'))
print("inference result")
display(Audio(base+'eval-322000_ref-csnt-140616-0050-140616-xijunm-0001-XIJUNM_0046614_0046884_M.wav'))
print("k e3 xi1 b u4 zhi1 d ao5 pau0 y ou3 m ei2 y ou3 f eng4 h jieu ang2 b jiei an4 l ao3 sh u3 pau0")
print("可惜不知道有没有凤凰变老鼠")
display(Audio(base+'text_perturbations_eval-322000_ref-csnt-140616-0050-140616-xijunm-0001-XIJUNM_0046614_0046884_M.wav'))
print("Chinese: pau0 w o3 w an2 w ei1 ch eng2 shi4 pau0 h jieu o4 d e2 yi1 l iu4 er4 wu3 j in1 b i4 pau0 h e2 yi1 l ing2 j ing1 y an4 pau0 zh en1 b u5 l ai4 pau0")
print("我玩微城市，获得一六二五金币和一零金币，真不赖")
display(Audio(base+'diff_text_eval-322000_ref-csnt-140616-0050-140616-xijunm-0001-XIJUNM_0046614_0046884_M.wav'))
# Out:
# ==================CHINESE==================
# Chinese: d an4 b u4 zhi1 d ao5 pau0 y ou3 m ei2 y ou3 f eng4 h jieu ang2 b jiei an4 wu1 y a1 pau0
# 但不知道有没有凤凰变乌鸦
# reference audio
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# inference result
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# k e3 xi1 b u4 zhi1 d ao5 pau0 y ou3 m ei2 y ou3 f eng4 h jieu ang2 b jiei an4 l ao3 sh u3 pau0
# 可惜不知道有没有凤凰变老鼠
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Chinese: pau0 w o3 w an2 w ei1 ch eng2 shi4 pau0 h jieu o4 d e2 yi1 l iu4 er4 wu3 j in1 b i4 pau0 h e2 yi1 l ing2 j ing1 y an4 pau0 zh en1 b u5 l ai4 pau0
# 我玩微城市，获得一六二五金币和一零金币，真不赖
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("\n===unparallel===\n")
base = '/home/zhx66/mnt/experiment/gst-guide/gst-tacotron-ljspeech/unparallel/0235/'
print("English: I want forgiveness of man; I want those doors (of the prison) opened.")
print("reference audio")
display(Audio(base+'LJ014-0235.wav'))
print("English: Neither the Dallas police nor the FBI had yet learned the source of the handbill.")
print("inference result")
display(Audio(base+'eval-314000_ref-LJ014-0235.wav'))


print("\n===unparallel===\n")
base = '/home/zhx66/mnt/experiment/gst-guide/gst-tacotron-ljspeech/unparallel/0065/'
print("English: Neither the Dallas police nor the FBI had yet learned the source of the handbill.")
print("reference audio")
display(Audio(base+'LJ029-0065.wav'))
print("inference result")
print("English: I want forgiveness of man; I want those doors (of the prison) opened.")
display(Audio(base+'eval-314000_ref-LJ029-0065.wav'))
# Out:
# ===unparallel===
#
# English: I want forgiveness of man; I want those doors (of the prison) opened.
# reference audio
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# English: Neither the Dallas police nor the FBI had yet learned the source of the handbill.
# inference result
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ===unparallel===
#
# English: Neither the Dallas police nor the FBI had yet learned the source of the handbill.
# reference audio
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# inference result
# English: I want forgiveness of man; I want those doors (of the prison) opened.
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
